# %%
#Assignment 1 Activation functions

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def tanh(x):
    return np.tanh(x)

# %%
def relu(x):
    return np.maximum(0,x)

# %%
def softmax(x):
    return np.exp(x)/np.sum(np.exp(x))

# %%
x=np.linspace(-10,10,100)

# %%
fig,axs=plt.subplots(2,2,figsize=(8,8))
axs[0,0].plot(x,sigmoid(x))
axs[0,0].set_title("Sigmoid")
axs[0,1].plot(x,tanh(x))
axs[0,1].set_title("Tanh")
axs[1,0].plot(x,relu(x))
axs[1,0].set_title("ReLU")
axs[1,1].plot(x,softmax(x))
axs[1,1].set_title("Softmax")

fig.suptitle("Common Activation functions")
# Out:
# Text(0.5, 0.98, 'Common Activation functions')

# %%
'''
This Python program demonstrates plotting of common activation functions using NumPy and Matplotlib libraries.

1. Importing Libraries: The program starts by importing the necessary libraries:
   - `numpy` (imported as `np`) for numerical computations.
   - `matplotlib.pyplot` (imported as `plt`) for plotting graphs.

2. Activation Functions: The program defines four common activation functions:
   - `sigmoid(x)`: Computes the sigmoid function for the input `x`, defined as 1/(1+exp(-x)).
   - `tanh(x)`: Computes the hyperbolic tangent function for the input `x`, defined as tanh(x).
   - `relu(x)`: Computes the rectified linear unit (ReLU) function for the input `x`, defined as maximum(0,x).
   - `softmax(x)`: Computes the softmax function for the input `x`, often used in multi-class classification problems. It exponentiates each element of `x` and normalizes the result to obtain a probability distribution, defined as exp(x)/sum(np.exp(x)).

3. Plotting Activation Functions: The program generates an array `x` containing 100 evenly spaced values from -10 to 10 using `np.linspace()`. Then, it creates a 2x2 subplot grid using `plt.subplots()`, with a figure size of 8x8 inches.

4. Plotting Each Activation Function: For each subplot, it plots one of the activation functions against the values in `x`:
   - `sigmoid(x)` is plotted on the first subplot (top-left).
   - `tanh(x)` is plotted on the second subplot (top-right).
   - `relu(x)` is plotted on the third subplot (bottom-left).
   - `softmax(x)` is plotted on the fourth subplot (bottom-right).
   
   For each subplot, a title is set using `.set_title()` with the corresponding activation function's name.

5. Setting Figure Title: Finally, a main title for the entire figure is set using `fig.suptitle()`.

'''
# Out:
# "\nThis Python program demonstrates plotting of common activation functions using NumPy and Matplotlib libraries.\n\n1. Importing Libraries: The program starts by importing the necessary libraries:\n   - `numpy` (imported as `np`) for numerical computations.\n   - `matplotlib.pyplot` (imported as `plt`) for plotting graphs.\n\n2. Activation Functions: The program defines four common activation functions:\n   - `sigmoid(x)`: Computes the sigmoid function for the input `x`, defined as 1/(1+exp(-x)).\n   - `tanh(x)`: Computes the hyperbolic tangent function for the input `x`, defined as tanh(x).\n   - `relu(x)`: Computes the rectified linear unit (ReLU) function for the input `x`, defined as maximum(0,x).\n   - `softmax(x)`: Computes the softmax function for the input `x`, often used in multi-class classification problems. It exponentiates each element of `x` and normalizes the result to obtain a probability distribution, defined as exp(x)/sum(np.exp(x)).\n\n3. Plotting Activation Funct
# ...
